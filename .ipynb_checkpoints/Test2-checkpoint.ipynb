# %%
import pandas as pd
import numpy as np
from datetime import datetime
import matplotlib.pyplot as plt
import yfinance as yf

# %%
apple= yf.Ticker("aapl")

# %%
apple.options[0]
# Out:
# '2021-02-18'

# %%
opt = apple.option_chain(date=apple.options[0])

# %%
opt.calls
# Out:
#          contractSymbol       lastTradeDate  strike  lastPrice     bid  \
# 0   AAPL210219C00025000 2021-02-17 16:12:11    25.0     105.41  105.85
# 1   AAPL210219C00030000 2021-02-17 19:04:14    30.0     100.67  100.85
# 2   AAPL210219C00035000 2021-02-17 14:41:36    35.0      96.50   95.70
# 3   AAPL210219C00040000 2021-02-11 16:20:50    40.0      95.05   90.65
# 4   AAPL210219C00045000 2021-02-04 14:48:38    45.0      90.65   85.60
# ..                  ...                 ...     ...        ...     ...
# 79  AAPL210219C00210000 2021-02-16 17:20:47   210.0       0.01    0.00
# 80  AAPL210219C00215000 2021-02-08 19:09:27   215.0       0.01    0.00
# 81  AAPL210219C00220000 2021-02-05 14:44:48   220.0       0.01    0.00
# 82  AAPL210219C00225000 2021-02-05 15:03:00   225.0       0.01    0.00
# 83  AAPL210219C00230000 2021-02-16 19:53:20   230.0       0.01    0.00
#
#        ask    change  percentChange  volume  openInterest  impliedVolatility  \
# ...
